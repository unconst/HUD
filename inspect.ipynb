# %%
from hud import HUD
W = HUD.load_from_config(project="W")
B = HUD.load_from_config(project="B")

# %%
B[:5].is_registered()
# Out:
# Running: <function HUD._is_registered.<locals>.__get_is_registered at 0x11c43d9d0>: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# {N(B-B0): False, N(B-B1): True, N(B-B2): True, N(B-B3): False, N(B-B4): True}

# %%
B[0].is_running()
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/t2/n8qztvk54892_y4rgslzz_wm0000gn/T/ipykernel_66862/997256599.py:1 in        │
# │ <module>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/t2/n8qztvk54892_y4rgslzz_wm0000gn/T/ipykernel_66862/997256599.py'           │
# │ /Users/thebes/Work/HUD/hud.py:417 in is_running                                           │
# │                                                                                           │
# │   414 │   │   HUD._run( neurons, script = "sudo apt-get update && sudo apt-get install -- │
# ...
