# %%
from hud import HUD

# %%
neurons = HUD.load_all_from_config()

# %%
neurons
# Out:
# {
#     'Marius': [
#         neuron(Marius-M0,/Users/thebes/.ssh/marius,137.184.97.177,Wallet (Marius, M0, ~/.bittensor/wallets/)),
#         neuron(Marius-M1,/Users/thebes/.ssh/marius,137.184.130.112,Wallet (Marius, M1, ~/.bittensor/wallets/)),
#         neuron(Marius-M10,/Users/thebes/.ssh/marius,159.223.188.119,Wallet (Marius, M10, ~/.bittensor/wallets/)),
#         neuron(Marius-M11,/Users/thebes/.ssh/marius,159.223.186.108,Wallet (Marius, M11, ~/.bittensor/wallets/)),
#         neuron(Marius-M12,/Users/thebes/.ssh/marius,159.223.186.122,Wallet (Marius, M12, ~/.bittensor/wallets/)),
#         neuron(Marius-M13,/Users/thebes/.ssh/marius,159.223.186.126,Wallet (Marius, M13, ~/.bittensor/wallets/)),
#         neuron(Marius-M14,/Users/thebes/.ssh/marius,143.244.158.64,Wallet (Marius, M14, ~/.bittensor/wallets/)),
#         neuron(Marius-M15,/Users/thebes/.ssh/marius,147.182.165.36,Wallet (Marius, M15, ~/.bittensor/wallets/)),
# ...

# %%
HUD.status( neurons['jello'] )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:36<00:00,  3.64s/it]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
# ...
